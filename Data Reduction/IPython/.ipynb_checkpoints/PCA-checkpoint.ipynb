# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA

# %% [markdown]
# # Load data

# %%
data = pd.read_csv(r'D:\Data Mining\Data Reduction\IPython\data\b5.csv')
data.head()
# Out:
#    E1  E2  E3  E4  E5  E6  E7  E8  E9  E10  ...  O1  O2  O3  O4  O5  O6  O7  \
# 0   4   2   5   2   5   1   4   3   5    1  ...   4   1   3   1   5   1   4
# 1   2   2   3   3   3   3   1   5   1    5  ...   3   3   3   3   2   3   3
# 2   5   1   1   4   5   1   1   5   5    1  ...   4   5   5   1   5   1   5
# 3   2   5   2   4   3   4   3   4   4    5  ...   4   3   5   2   4   2   5
# 4   3   1   3   3   3   1   3   1   3    5  ...   3   1   1   1   3   1   3
#
#    O8  O9  O10
# 0   2   5    5
# 1   1   3    2
# 2   5   5    5
# 3   2   5    5
# 4   1   5    3
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Convert data to numpy array

# %%
X = data.values
X
# Out:
# array([[4, 2, 5, ..., 2, 5, 5],
#        [2, 2, 3, ..., 1, 3, 2],
#        [5, 1, 1, ..., 5, 5, 5],
#        ...,
#        [2, 5, 4, ..., 5, 5, 5],
#        [1, 4, 2, ..., 3, 5, 5],
#        [2, 3, 1, ..., 5, 5, 5]], dtype=int64)

# %% [markdown]
# ## Scale the values

# %%
X = scale(X)
X
# Out:
# array([[ 1.112632  , -0.57855181,  1.28086553, ..., -0.96448433,
#          0.88177594,  1.0099427 ],
#        [-0.51209309, -0.57855181, -0.33817724, ..., -1.76030372,
#         -1.15794039, -2.03840414],
#        [ 1.92499454, -1.34069418, -1.95722   , ...,  1.42297383,
#          0.88177594,  1.0099427 ],
#        ...,
#        [-0.51209309,  1.70787529,  0.47134415, ...,  1.42297383,
#          0.88177594,  1.0099427 ],
#        [-1.32445564,  0.94573292, -1.14769862, ..., -0.16866494,
#          0.88177594,  1.0099427 ],
#        [-0.51209309,  0.18359055, -1.95722   , ...,  1.42297383,
#          0.88177594,  1.0099427 ]])

# %% [markdown]
# # Conduct PCA
# ## PCA with 50 components

# %%
pca = PCA()
pca.fit(X)
print(pca.explained_variance_ratio_)
# Out:
# [0.16101911 0.09246263 0.07527279 0.07100381 0.05526279 0.0313044
#  0.02660753 0.02099101 0.01937029 0.01849593 0.01794133 0.01735232
#  0.01689316 0.01604282 0.01576013 0.01470117 0.01459846 0.01438242
#  0.01362569 0.01322527 0.0131285  0.01268631 0.01223362 0.01180048
#  0.01164071 0.01136677 0.01108761 0.0106515  0.01045028 0.0102118
#  0.01003675 0.00983507 0.00974897 0.00963948 0.0089566  0.00894
#  0.00868373 0.00840808 0.00831106 0.00808253 0.00793945 0.00760062
#  0.00748126 0.00727417 0.00694749 0.00689884 0.00650197 0.00647554
#  0.0062404  0.00442735]

# %% [markdown]
# ## PCA with 5 components

# %%
pca5 = PCA(n_components=5)
pca5.fit(X)
print(pca5.explained_variance_ratio_)
# Out:
# [0.16101911 0.09246262 0.07527277 0.07100378 0.05526126]

# %% [markdown]
# ## Contributions of variables to components

# %%
print(pca5.components_)
# Out:
# [[-0.18391002  0.17969489 -0.25064842  0.20613724 -0.23166859  0.19768006
#   -0.22070018  0.13297568 -0.16463502  0.20183555  0.1546586  -0.12978284
#    0.12271664 -0.10236672  0.14227665  0.16681316  0.16277721  0.17394463
#    0.17756967  0.19476215  0.0925596  -0.17766441  0.09908331 -0.11467391
#    0.13341581 -0.05636317  0.18786055 -0.13286109 -0.11972998 -0.18783914
#   -0.11091545  0.05024015 -0.0732428   0.15189972 -0.10873846  0.09267711
#   -0.04455606  0.13905392 -0.0913069  -0.0952188  -0.06943437  0.09889362
#   -0.03539124  0.07185461 -0.13054273  0.08698101 -0.11182013 -0.01241735
#    0.00436645 -0.11687606]
#  [-0.12863016  0.16744097 -0.07309308  0.09549423 -0.14848006  0.12810298
#   -0.13659348  0.10833569 -0.11567924  0.07576682 -0.22728337  0.14364664
#   -0.21602468  0.11924513 -0.18824384 -0.25219981 -0.24454755 -0.24842501
#   -0.19626417 -0.18517187  0.0848301  -0.17626849 -0.05187776 -0.19235053
#    0.17352285 -0.17871415  0.17026317 -0.14028746 -0.20734274 -0.09458994
#    0.12416291 -0.16245744  0.04189369 -0.20153325  0.11327086 -0.16958208
#    0.07220898 -0.11061447  0.07162881  0.05406641 -0.01405357 -0.0288401
#   -0.10895123  0.02693923 -0.02196441  0.06267753  0.03790001 -0.0456607
#   -0.0900138  -0.06994048]
#  [ 0.15472032 -0.14204431  0.06430837 -0.16684804  0.08700513 -0.10330566
#    0.12545697 -0.19084286  0.17678822 -0.15790229 -0.12675214  0.10491893
#   -0.18018366  0.05551418 -0.03573452 -0.08463469 -0.00680586 -0.00971229
#   -0.02361294 -0.06606905  0.14081625 -0.07867396  0.20508992 -0.24968086
#    0.17244111 -0.22635436  0.11287106 -0.18876479 -0.22318434 -0.07487136
#   -0.18955283  0.18295463 -0.18237035  0.14803169 -0.20995159  0.18970486
#   -0.22814707  0.18091446 -0.24098544 -0.17501018  0.03028081 -0.03904965
#    0.0243436  -0.01214376  0.03018462 -0.03345914 -0.01392843  0.06326245
#   -0.12674848  0.04912905]
#  [ 0.06426954 -0.07072687  0.1138344  -0.08785464  0.06372657  0.03434185
#    0.08313697 -0.04987886  0.01024522 -0.07698249 -0.0072642   0.01088949
#   -0.03035206  0.06480803  0.03462899  0.00499617 -0.04204567 -0.03814934
#   -0.04653099 -0.08908923 -0.0053084   0.05271058 -0.08482181  0.06929542
#   -0.07288431  0.09194415 -0.08043173  0.05104058  0.0402212   0.03248383
#   -0.08180751 -0.03831085 -0.16653293 -0.01437942  0.03788113 -0.01478119
#   -0.05529431  0.00591737  0.00368026 -0.14299175 -0.32941468  0.29348436
#   -0.28990225  0.25283373 -0.29774844  0.25763712 -0.26778527 -0.32531272
#   -0.20937819 -0.33019915]
#  [ 0.14993398 -0.12963544  0.06733719 -0.13565183  0.13085535 -0.07170023
#    0.12708387 -0.14175525  0.15509776 -0.11145022  0.14175668 -0.14623918
#    0.10353973  0.00153652  0.1219757   0.15422762  0.16151046  0.16582035
#    0.22753536  0.04986669  0.1770773  -0.10934998  0.16724051 -0.20730407
#    0.19325131 -0.14170735  0.15400522 -0.14137915 -0.14290037 -0.02408485
#    0.21282241 -0.19880902  0.11515185 -0.11635231  0.23636969 -0.19491463
#    0.22219674 -0.09025592  0.24858748  0.16707521 -0.01923575  0.11504735
#   -0.05530252  0.15272935  0.06829679  0.07025855  0.02582234  0.00120345
#   -0.06816529  0.0090005 ]]
